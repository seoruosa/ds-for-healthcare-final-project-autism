# %%
from google.colab import drive

ROOT = "/content/drive"
print(ROOT)

drive.mount(ROOT)

# %% [markdown]
# Follow the instructions returned by function

# %%
# %cd /content

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = 'My Drive/colab-projects/' 
PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# %cd {PROJECT_PATH}
# %pwd

# %%
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join  

# replace with your Github username 
GIT_USERNAME = "GIT_USERNAME"

# definitely replace with your
GIT_TOKEN = "{YOUR_GITHUB_TOKEN}" 

# Replace with your github repository in this case we want 
GIT_REPOSITORY = "ds-for-healthcare-final-project-autism" 

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"

GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)

# %%
# Change directory to the location defined in project_path
# %cd "{PROJECT_PATH}/{GIT_REPOSITORY}"
# clone the github repository
# !git clone "{GIT_PATH}"
# Out:
# /content/drive/My Drive/colab-projects/ds-for-healthcare-final-project-autism
# Cloning into 'ds-for-healthcare-final-project-autism'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 35 (delta 11), reused 28 (delta 6), pack-reused 0
# Unpacking objects: 100% (35/35), done.

# %%
# !git pull
# !git status

# %%
# !git config --global user.email "your@email"
# !git config --global user.name {GIT_USERNAME}

# %%
# !git status
# !git add *
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git commit -m '"your commit message"'

# %%
# !git remote set-url origin {GIT_PATH}

# %%
# !git push -u origin master

# %% [markdown]
# # New Section
